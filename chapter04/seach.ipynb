# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.parse import urljoin

ignorewords=set(['the','of','to','and','a','in','is','it'])

class crawler:
   # 데이터베이스 이름으로 크롤러 초기화
   def __init__(self,dbname):
     pass
 
   def __del__(self):
     pass

   def dbcommit(self):
     pass
   
   # 항목번호를 얻고 등재되지 않았다면 추가하는 보조함수
   def getentryid(self,table,field,value,createnew=True):
     return None

   # 개별 페이지를 색인
   def addtoindex(self,url,soup):
     print ('Indexing %s' % url)
   
   # HTML 페이지에서 텍스트를 추출함(태그 추출은 안함!!!
   def gettextonly(self,soup):
     return None;
  
   # 공백문자가 아닌 문자들로 단어를 분리함
   def seperatewords(self,text):
     return None;
   
   # 이미 색인한 주소라면 true
   def isindexed(self,url):
     return False;
   
   # 두페이지 간의 링크 추가
   def addlinkref(self, urlFrom,urlTo,linkText):
     pass
   
   def crawl(self,pages,depth=2):
       for i in range(depth):
         newpages={}
         for page in pages:
           try:
             c=urlopen(page)
           except Exception as e :
             print ('Could not open %s"' % page)
             print(e)   
                
             continue
           try:
             soup=BeautifulSoup(c.read())
             self.addtoindex(page,soup)
             links=soup('a')
             for link in links:
               if ('href' in dict(link.attrs)):
                 url=urljoin(page,link['href'])
                 if url.find("'")!=-1: continue
                 url=url.split('#')[0]  # remove location portion
                 if url[0:4]=='http' and not self.isindexed(url):
                   newpages[url]=1
                 linkText=self.gettextonly(link)
                 self.addlinkref(page,url,linkText)
             self.dbcommit()
           except Exception as e:
             print ("Could not parse page %s" % page) 
             print (e)

         pages=newpages
       

           

pagelist=['https://en.wikipedia.org/wiki/Python_(programming_language)']
crawler=crawler('')
crawler.crawl(pagelist)
# Out:
# /home/kdo/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Indexing https://en.wikipedia.org/wiki/Python_(programming_language)
# Indexing https://si.wikipedia.org/wiki/%E0%B6%B4%E0%B6%BA%E0%B7%92%E0%B6%AD%E0%B6%B1%E0%B7%8A
# Indexing https://en.wikipedia.org/wiki/List_of_free_and_open-source_Android_applications
# Indexing https://en.wikipedia.org/wiki/Unicode
# Could not open https://www.python.org/dev/intro/"
# HTTP Error 404: OK
# Indexing https://en.wikipedia.org/wiki/Lambda_(programming)
# Indexing https://en.wikipedia.org/wiki/COBOL
# Indexing https://docs.python.org/py3k/library/functions.html
# Indexing https://en.wikipedia.org/wiki/Floating_point
# Indexing https://en.wikipedia.org/wiki/Half-open_interval
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=1
# Indexing https://en.wikipedia.org/wiki/Method_(computing)
# Indexing https://en.wikipedia.org/wiki/Here_document
# Indexing https://or.wikipedia.org/wiki/%E0%AC%AA%E0%AC%BE%E0%AC%87%E0%AC%A5%E0%AC%A8%E0%AD%8D_(%E0%AC%AA%E0%AD%8D%E0%AC%B0%E0%AD%8B%E0%AC%97%E0%AD%8D%E0%AC%B0%E0%AC%BE%E0%AC%AE%E0%AC%BF%E0%AC%82_%E0%AC%AD%E0%AC%BE%E0%AC%B7%E0%AC%BE)
# Indexing https://en.wikipedia.org/wiki/General-purpose_programming_language
# Indexing https://azb.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86
# Indexing https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86
# Indexing https://en.wikipedia.org/wiki/Name_resolution_(programming_languages)
# Indexing https://en.wikipedia.org/wiki/Dylan_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Red_Hat_Linux
# Indexing https://en.wikipedia.org/wiki/Anonymous_function
# Indexing https://en.wikipedia.org/wiki/Python_syntax_and_semantics
# Indexing https://el.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Bottle_(web_framework)
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=history
# Indexing https://he.wikipedia.org/wiki/%D7%A4%D7%99%D7%99%D7%AA%D7%95%D7%9F
# Indexing https://en.wikipedia.org/wiki/Late_binding
# Indexing https://en.wikipedia.org/wiki/Category:CS1_maint:_Multiple_names:_authors_list
# Indexing https://en.wikipedia.org/wiki/CLPython
# Indexing https://als.wikipedia.org/wiki/Python_(Programmiersprache)
# Indexing https://en.wikipedia.org/wiki/Information_security
# Indexing https://en.wikipedia.org/wiki/Just_in_time_compiler
# Indexing https://en.wikipedia.org/wiki/Finite_element_method
# Indexing https://en.wikipedia.org/wiki/Microsoft_Open_Specification_Promise
# Indexing https://en.wikipedia.org/wiki/List_of_free_software_web_applications
# Indexing https://en.wikipedia.org/wiki/Coroutine
# Indexing https://en.wikipedia.org/w/index.php?title=Template:Python_(programming_language)&action=edit
# Indexing https://en.wikipedia.org/wiki/Graphical_user_interface
# Indexing https://en.wikipedia.org/wiki/Help:Contents
# Indexing https://en.wikipedia.org/wiki/Dialect_(computing)
# Indexing https://en.wikipedia.org/wiki/List_of_formerly_proprietary_software
# Indexing https://en.wikipedia.org/wiki/Object_language
# Indexing https://en.wikipedia.org/wiki/Reference_implementation
# Indexing https://en.wikipedia.org/wiki/Pyrex_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Ported
# Indexing https://en.wikipedia.org/wiki/Template:Python_web_frameworks
# Indexing https://en.wikipedia.org/wiki/List_of_free_and_open-source_software_organizations
# Indexing https://en.wikipedia.org/wiki/Natural_language_processing
# Indexing https://en.wikipedia.org/wiki/Reflection_(computer_science)
# Indexing https://en.wikipedia.org/wiki/List_of_open-source_routing_platforms
# Indexing https://en.wikipedia.org/wiki/Linux_distribution
# Indexing https://en.wikipedia.org/wiki/Comparison_of_free_geophysics_software
# Could not open http://ebeab.com/2014/01/21/python-culture/"
# HTTP Error 404: Not Found
# Indexing https://en.wikipedia.org/wiki/While_loop
# Indexing https://www.python.org/downloads/release/python-351/
# Indexing http://www.linuxdevcenter.com/pub/a/linux/2001/11/29/ruby.html
# Indexing https://en.wikipedia.org/wiki/Symbian
# Indexing https://en.wikipedia.org/wiki/Comparison_of_free_software_for_audio
# Indexing https://en.wikipedia.org/wiki/Industrial_Light_%26_Magic
# Indexing https://en.wikipedia.org/wiki/Memory_management
# Indexing https://zh-yue.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Web_framework
# Indexing https://en.wikipedia.org/wiki/Web2py
# Indexing https://eu.wikipedia.org/wiki/Python_(informatika)
# Indexing https://en.wikipedia.org/wiki/Standard_ML
# Indexing https://en.wikipedia.org/wiki/Gradual_typing
# Indexing http://www.wayforward.net/pycontract/
# Indexing https://en.wikipedia.org/wiki/Python_(programming_language)
# Could not open https://docs.python.org/lib/module-itertools.html"
# HTTP Error 404: Not Found
# Indexing https://en.wikipedia.org/wiki/Beerware
# Indexing https://www.python.org/dev/peps/pep-0289/
# Indexing https://en.wikipedia.org/wiki/Fedora_(operating_system)
# Indexing https://en.wikipedia.org/wiki/Berkeley_Software_Distribution
# Indexing https://en.wikipedia.org/wiki/Printf
# Indexing http://www.artima.com/weblogs/viewpost.jsp?thread=147358
# Indexing https://en.wikipedia.org/wiki/TACTIC_(web_framework)
# Indexing https://en.wikipedia.org/wiki/Bug_tracker
# Indexing https://en.wikipedia.org/wiki/Category:Free_software
# Indexing https://en.wikipedia.org/wiki/GNU
# Indexing https://docs.python.org/reference/datamodel.html
# Indexing https://km.wikipedia.org/wiki/%E1%9E%95%E1%9E%B6%E1%9E%99%E1%9E%90%E1%9E%BB%E1%9E%93
# Indexing https://en.wikipedia.org/wiki/Python_Package_Index
# Indexing http://arxiv.org/abs/1404.6388
# Indexing https://en.wikipedia.org/wiki/Instance_data
# Indexing https://en.wikipedia.org/wiki/Character_string
# Indexing https://bs.wikipedia.org/wiki/Python_(programski_jezik)
# Indexing https://en.wikipedia.org/wiki/One_Laptop_per_Child
# Indexing http://python-history.blogspot.com/2009/01/brief-timeline-of-python.html
# Indexing https://en.wikipedia.org/wiki/Portal:Python_programming
# Indexing https://en.wikipedia.org/wiki/Category:Good_articles
# Indexing http://www.2ality.com/2013/02/javascript-influences.html
# Indexing https://en.wikipedia.org/wiki/LibreOffice
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=14
# Indexing https://en.wikipedia.org/wiki/Open-source_software
# Indexing https://en.wikipedia.org/wiki/Free_software_license
# Indexing https://en.wikipedia.org/wiki/Lazy_evaluation
# Indexing https://en.wikipedia.org/wiki/Python_Software_Foundation
# Indexing https://en.wikiversity.org/wiki/Topic:Python
# Indexing http://python-history.blogspot.co.uk/
# Indexing https://en.wikipedia.org/wiki/Raw_string
# Indexing https://en.wikipedia.org/wiki/Mercurial
# Indexing https://sk.wikipedia.org/wiki/Python_(programovac%C3%AD_jazyk)
# Indexing https://en.wikipedia.org/wiki/Static_typing
# Indexing https://simple.wikipedia.org/wiki/Python_(programming_language)
# Indexing http://www.troeger.eu/teaching/pythonvm08.pdf
# Indexing https://en.wikipedia.org/wiki/Visual_Basic_.NET
# Indexing https://wuu.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Apple_Public_Source_License
# Indexing https://en.wikipedia.org/wiki/Procedural_programming
# Indexing https://bg.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Nuke_(software)
# Indexing https://en.wikipedia.org/wiki/Guido_van_Rossum
# Indexing http://radio.weblogs.com/0112098/2003/08/29.html
# Indexing https://creativecommons.org/licenses/by-sa/3.0/
# Indexing http://nondot.org/sabre
# Indexing https://en.wikipedia.org/wiki/Google
# Indexing https://en.wikipedia.org/wiki/Julia_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Nagare_(web_framework)
# Indexing https://web.archive.org/20140423121309/http://www.jasc.com/support/customercare/articles/psp9components.asp
# Indexing https://en.wikipedia.org/wiki/Garbage_collection_(computer_science)
# Indexing https://en.wikipedia.org/wiki/Exception_handling_syntax
# Indexing https://en.wikipedia.org/wiki/Operating_system
# Indexing https://ml.wikipedia.org/wiki/%E0%B4%AA%E0%B5%88%E0%B4%A4%E0%B5%8D%E0%B4%A4%E0%B5%BA_(%E0%B4%AA%E0%B5%8D%E0%B4%B0%E0%B5%8B%E0%B4%97%E0%B5%8D%E0%B4%B0%E0%B4%BE%E0%B4%AE%E0%B4%BF%E0%B4%99%E0%B5%8D%E0%B4%99%E0%B5%8D_%E0%B4%AD%E0%B4%BE%E0%B4%B7)
# Indexing https://en.wikipedia.org/wiki/Programming_paradigm
# Indexing https://en.wikipedia.org/wiki/Comparison_of_programming_languages
# Indexing https://www.wikidata.org/wiki/Q28865
# Indexing https://en.wikipedia.org/wiki/Associative_array
# Indexing https://en.wikipedia.org/wiki/Sugar_Labs
# Indexing https://en.wikipedia.org/wiki/Numerical_mathematics
# Indexing https://en.wikipedia.org/wiki/Hypertext_Transfer_Protocol
# Indexing https://en.wikipedia.org/wiki/Template:Programming_languages
# Indexing https://en.wikipedia.org/wiki/SciPy
# Indexing https://en.wikipedia.org/wiki/Django_(web_framework)
# Indexing http://people.csail.mit.edu/mikelin/ocaml+twt/
# Indexing https://hi.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8_(%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%A8_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE)
# Indexing https://en.wikipedia.org/wiki/Yukihiro_Matsumoto
# Indexing https://en.wikipedia.org/wiki/Cobra_(programming_language)
# Indexing https://et.wikipedia.org/wiki/Python_(programmeerimiskeel)
# Indexing https://zh-min-nan.wikipedia.org/wiki/Python
# Indexing http://speed.pypy.org/
# Indexing https://docs.python.org/faq/design.html
# Indexing https://ro.wikipedia.org/wiki/Python
# Indexing https://www.python.org/dev/peps/pep-0380/
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&printable=yes
# Indexing https://en.wikipedia.org/wiki/Python_Software_Foundation_License
# Indexing https://en.wikipedia.org/wiki/Wikipedia:Citing_sources
# Indexing http://cdsweb.cern.ch/journal/CERNBulletin/2006/31/News%20Articles/974627?ln=en
# Indexing https://en.wikipedia.org/wiki/Pascal_(programming_language)
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=info
# Indexing https://en.wikipedia.org/wiki/Astropy
# Indexing https://en.wikipedia.org/wiki/Pointer_(computer_programming)
# Indexing https://en.wikipedia.org/wiki/Nim_(programming_language)
# Could not open http://cutter.rexx.com/~dkuhlman/python_book_01.html"
# HTTP Error 404: Not Found
# Indexing https://www.python.org/dev/peps/pep-0237/
# Indexing https://en.wikipedia.org/wiki/MIT_License
# Indexing https://www.python.org/dev/peps/pep-0333/
# Indexing https://en.wikipedia.org/wiki/Computer_file
# Indexing https://en.wikipedia.org/wiki/Whitespace_character
# Indexing https://en.wikipedia.org/wiki/Library_of_Congress_Control_Number
# Indexing https://en.wikipedia.org/wiki/List_of_word_processors
# Indexing https://en.wikipedia.org/wiki/Just-in-time_compilation
# Indexing https://en.wikipedia.org/wiki/Nevow
# Indexing https://en.wikipedia.org/wiki/Pyramid_(web_framework)
# Indexing https://en.wikipedia.org/wiki/File:Python-logo-notext.svg
# Indexing https://mail.python.org/pipermail/python-dev/2002-April/022739.html
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=3
# Indexing https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_August_2015
# Indexing https://bug.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Nokia
# Indexing https://en.wikipedia.org/wiki/GNU_General_Public_License
# Indexing https://en.wikipedia.org/wiki/Zlib_License
# Could not open https://www.h2desk.com/blog/python-scientific-computing/"
# HTTP Error 403: Forbidden
# Indexing https://en.wikipedia.org/wiki/Wikipedia:Community_portal
# Indexing http://www.tiobe.com/index.php/paperinfo/tpci/Python.html
# Indexing https://en.wikipedia.org/wiki/Relational_database
# Indexing https://wikimediafoundation.org/
# Indexing https://en.wikipedia.org/wiki/Generator_(computer_science)
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=4
# Indexing https://en.wikipedia.org/wiki/Wikipedia:Wikimedia_sister_projects
# Indexing https://tg.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Inkscape
# Indexing https://en.wikipedia.org/wiki/Grok_(web_framework)
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=5
# Indexing http://shop.oreilly.com/product/9780596007973.do
# Indexing https://en.wikipedia.org/wiki/Reference_counting
# Indexing https://en.wikipedia.org/wiki/The_Free_Software_Definition
# Indexing https://en.wikipedia.org/wiki/Unix-like
# Indexing https://en.wikipedia.org/wiki/Benevolent_dictator_for_life
# Could not open http://books.google.com/books?id=3JfE7TGUwvgC&pg=PT100"
# HTTP Error 401: Unauthorized
# Indexing https://en.wikipedia.org/wiki/Web_browser
# Indexing https://en.wikipedia.org/wiki/LLVM
# Indexing http://www.secnetix.de/~olli/Python/block_indentation.hawk
# Indexing https://en.wikipedia.org/w/index.php?title=Template:FOSS&action=edit
# Indexing https://my.wikipedia.org/wiki/Python_(programming_language)
# Indexing https://en.wikipedia.org/wiki/NetBSD
# Indexing https://en.wikipedia.org/wiki/List_of_open-source_video_games
# Indexing http://www.stochasticgeometry.ie/2010/04/29/python-on-the-nokia-n900/
# Indexing https://en.wikipedia.org/wiki/Programming_language
# Indexing https://en.wikipedia.org/wiki/D_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Category:Object-oriented_programming_languages
# Indexing https://en.wikipedia.org/wiki/ALGOL_68
# Indexing http://legacy.python.org/dev/peps/pep-0465/
# Indexing https://en.wikipedia.org/wiki/Special:MyContributions
# Indexing https://shop.wikimedia.org
# Indexing https://en.wikipedia.org/wiki/Common_Intermediate_Language
# Indexing https://ceb.wikipedia.org/wiki/Python_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Swift_(programming_language)
# Indexing https://wikimediafoundation.org/wiki/Terms_of_Use
# Indexing https://sr.wikipedia.org/wiki/%D0%9F%D0%B0%D1%98%D1%82%D0%BE%D0%BD_(%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B5%D0%B7%D0%B8%D0%BA)
# Indexing https://en.wikipedia.org/wiki/Filename_extension
# Indexing https://en.wikipedia.org/wiki/Fortran
# Indexing https://en.wikipedia.org/wiki/Command-line_interface
# Indexing https://en.wikiquote.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Alex_Martelli
# Indexing https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC
# Indexing https://lt.wikipedia.org/wiki/Python
# Indexing https://ru.wikipedia.org/wiki/Python
# Indexing http://www.computer.org/csdl/mags/cs/2011/02/mcs2011020009.html
# Indexing https://en.wikipedia.org/wiki/Ubiquity_(software)
# Indexing https://en.wikipedia.org/wiki/Shallow_copy
# Indexing https://en.wikipedia.org/wiki/List_of_open-source_bioinformatics_software
# Indexing http://www.tiobe.com/index.php/content/paperinfo/tpci/
# Indexing https://en.wikipedia.org/wiki/The_Cathedral_and_the_Bazaar
# Indexing https://en.wikipedia.org/wiki/Mathematics
# Indexing https://en.wikipedia.org/wiki/Pseudorandom_number_generator
# Indexing https://eo.wikipedia.org/wiki/Python_(programlingvo)
# Indexing https://en.wikipedia.org/wiki/List_of_free-software_events
# Indexing https://en.wikipedia.org/wiki/Smalltalk
# Indexing https://en.wikipedia.org/wiki/C89_(C_version)
# Indexing https://en.wikipedia.org/wiki/Algebra
# Indexing https://en.wikipedia.org/wiki/Artistic_License
# Indexing https://en.wikipedia.org/wiki/Blender_(software)
# Indexing https://gu.wikipedia.org/wiki/%E0%AA%AA%E0%AA%BE%E0%AA%AF%E0%AA%A5%E0%AB%8B%E0%AA%A8(%E0%AA%AA%E0%AB%8D%E0%AA%B0%E0%AB%8B%E0%AA%97%E0%AB%8D%E0%AA%B0%E0%AA%BE%E0%AA%AE%E0%AA%BF%E0%AA%82%E0%AA%97_%E0%AA%AD%E0%AA%BE%E0%AA%B7%E0%AA%BE)
# Indexing https://en.wikipedia.org/wiki/Array_slicing
# Indexing https://wiki.python.org/moin/PythonForArtificialIntelligence
# Indexing https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# Indexing https://en.wikipedia.org/wiki/CoffeeScript
# Indexing https://en.wikipedia.org/wiki/Immutable_object
# Indexing https://en.wikipedia.org/wiki/Scribus
# Indexing https://en.wikipedia.org/wiki/Template_talk:Programming_languages
# Indexing https://wikimediafoundation.org/wiki/Cookie_statement
# Indexing https://www.python.org/dev/peps/pep-0488/
# Indexing https://en.wikipedia.org/wiki/Unit_testing
# Indexing https://www.python.org/dev/peps/pep-3000/
# Indexing https://en.wikipedia.org/wiki/Twisted_(software)
# Indexing https://en.wikipedia.org/wiki/Portal:Current_events
# Indexing https://en.wikipedia.org/wiki/Artificial_intelligence
# Indexing https://docs.python.org/whatsnew/2.0.html
# Indexing https://kk.wikipedia.org/wiki/Python
# Indexing http://aima.cs.berkeley.edu/
# Indexing https://en.wikipedia.org/wiki/Groovy_(programming_language)
# Indexing https://commons.wikimedia.org/wiki/Category:Python_(programming_language)
# Indexing https://web.archive.org/20121101045354/http://wiki.python.org:80/moin/PythonForArtificialIntelligence
# Indexing http://insidetech.monster.com/training/articles/8114-15-ways-python-is-a-powerful-force-on-the-web
# Indexing https://www.dmoz.org/Computers/Programming/Languages/Python
# Indexing http://julialang.org/blog/2012/02/why-we-created-julia
# Indexing https://en.wikipedia.org/wiki/Long-term_support
# Indexing https://cs.wikipedia.org/wiki/Python
# Indexing https://docs.python.org/3.2/tutorial/controlflow.html
# Indexing https://en.wikipedia.org/wiki/Simple_DirectMedia_Layer
# Indexing https://en.wikipedia.org/wiki/Special:RecentChanges
# Indexing https://en.wikipedia.org/wiki/Mozilla_Corporation_software_rebranded_by_the_Debian_project
# Indexing https://wikimediafoundation.org/wiki/Privacy_policy
# Indexing https://en.wikipedia.org/wiki/Special:BookSources/9780735636972
# Indexing https://en.wikipedia.org/wiki/List_(computer_science)
# Indexing https://en.wikipedia.org/wiki/String_literal
# Could not open http://wiki.ecmascript.org/doku.php?id=proposals:iterators_and_generators"
# <urlopen error [Errno 110] Connection timed out>
# Indexing https://en.wikipedia.org/wiki/Blogger_(service)
# Indexing https://www.python.org/dev/peps/pep-0006/
# Indexing https://en.wikipedia.org/wiki/Portage_(software)
# Indexing https://en.wikipedia.org/wiki/MIME
# Indexing https://en.wikipedia.org/wiki/Byte
# Indexing https://en.wikipedia.org/wiki/Java_virtual_machine
# Indexing https://en.wikipedia.org/wiki/Py2exe
# Indexing http://www.webcitation.org/5ru5VItfv
# Indexing https://en.wikipedia.org/wiki/Common_Lisp
# Indexing https://www.python.org/download/releases/3.0/
# Indexing https://vi.wikipedia.org/wiki/Python_(ng%C3%B4n_ng%E1%BB%AF_l%E1%BA%ADp_tr%C3%ACnh)
# Indexing https://en.wikipedia.org/wiki/PythonAnywhere
# Indexing https://en.wikipedia.org/wiki/Backporting
# Indexing https://en.wikipedia.org/wiki/Escape_character
# Indexing https://en.wikipedia.org/wiki/Non-English-based_programming_languages
# Indexing https://en.wikipedia.org/wiki/Object-oriented_programming
# Could not open https://en.wikipedia.org/w/index.php?title=Category:Python_web_application_frameworks&action=edit&redlink=1"
# HTTP Error 404: Not Found
# Indexing https://en.wikipedia.org/wiki/Peter_Norvig
# Indexing https://an.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Centrum_Wiskunde_%26_Informatica
# Could not open https://www.python.org/community/pycon/dc2004/papers/24/metaclasses-pycon.pdf"
# HTTP Error 404: OK
# Indexing https://en.wikipedia.org/wiki/Class_(computer_science)
# Indexing https://www.python.org/dev/peps/pep-0007/
# Indexing https://en.wikipedia.org/wiki/Immutable
# Indexing https://it.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Comparison_of_source_code_hosting_facilities
# Indexing https://en.wikipedia.org/wiki/List_of_open-source_software_for_mathematics
# Indexing https://www.python.org/dev/peps/pep-0327/
# Indexing https://la.wikipedia.org/wiki/Python
# Indexing http://www.pyinstaller.org/
# Indexing https://en.wikipedia.org/wiki/ABC_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Category:Python_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Free_software_movement
# Indexing https://en.wikipedia.org/wiki/Viral_license
# Indexing https://en.wikipedia.org/wiki/Category:Dutch_inventions
# Indexing https://en.wikipedia.org/wiki/Tornado_(web_server)
# Indexing https://en.wikipedia.org/wiki/Haskell_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Syntax_(programming_languages)
# Indexing https://en.wikipedia.org/wiki/Comparison_of_open-source_operating_systems
# Indexing http://neopythonic.blogspot.be/2009/04/tail-recursion-elimination.html
# Indexing https://en.wikipedia.org/wiki/Sage_(mathematics_software)
# Indexing https://en.wikipedia.org/wiki/Software_developer
# Indexing http://diveintopython.net
# Indexing https://en.wikipedia.org/wiki/Special:BookSources/978-1-59059-356-1
# Indexing https://en.wikipedia.org/wiki/Help:Authority_control
# Indexing https://ckb.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%86_(%D8%B2%D9%85%D8%A7%D9%86%DB%8C_%D8%A8%DB%95%D8%B1%D9%86%D8%A7%D9%85%DB%95%D8%B3%D8%A7%D8%B2%DB%8C)
# Indexing https://en.wikipedia.org/wiki/Open-source_software_development
# Indexing https://en.wikipedia.org/wiki/Eric_Python_IDE
# Indexing https://en.wikipedia.org/wiki/Free_and_open-source_graphics_device_driver
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=19
# Indexing https://en.wikipedia.org/wiki/Roundup_(issue_tracker)
# Could not open http://www.immunitysec.com/products-immdbg.shtml"
# HTTP Error 404: Not Found
# Indexing https://en.wikipedia.org/wiki/Flask_(web_framework)
# Indexing https://en.wikipedia.org/wiki/Single-board_computer
# Indexing https://en.wikipedia.org/wiki/The_Open_Source_Definition
# Indexing https://en.wikipedia.org/wiki/Debian_Free_Software_Guidelines
# Indexing https://en.wikipedia.org/wiki/Monty_Python
# Indexing https://en.wikipedia.org/wiki/Java_(software_platform)
# Indexing https://pl.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Object_(computer_science)
# Indexing https://en.wikipedia.org/wiki/Pylons_(web_framework)
# Indexing https://en.wikipedia.org/wiki/Assertion_(programming)
# Indexing https://en.wikipedia.org/wiki/String_interpolation
# Indexing http://python-history.blogspot.com/2010/08/why-pythons-integer-division-floors.html
# Indexing https://en.wikipedia.org/wiki/Matplotlib
# Indexing https://en.wikipedia.org/wiki/Structured_programming
# Indexing https://en.wikipedia.org/wiki/Special:RecentChangesLinked/Python_(programming_language)
# Indexing https://en.wikipedia.org/wiki/C_Sharp_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# Indexing https://en.wikipedia.org/wiki/Strongly_typed_programming_language
# Indexing https://en.wikipedia.org/wiki/Tail_call
# Indexing https://en.wikipedia.org/wiki/Apache_web_server
# Indexing https://sco.wikipedia.org/wiki/Python_(programmin_leid)
# Indexing https://www.python.org/download/releases/2.3/mro/
# Indexing https://en.wikipedia.org/wiki/Category:Dynamically_typed_programming_languages
# Indexing https://ta.wikipedia.org/wiki/%E0%AE%AA%E0%AF%88%E0%AE%A4%E0%AF%8D%E0%AE%A4%E0%AE%BE%E0%AE%A9%E0%AF%8D
# Indexing https://www.python.org/dev/peps/pep-0255/
# Indexing https://en.wikipedia.org/wiki/Template_talk:Python_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Template_talk:Python_web_frameworks
# Indexing https://en.wikibooks.org/wiki/Python_Programming
# Indexing https://en.wikipedia.org/wiki/Tuple
# Indexing http://cobra-language.com/docs/python/
# Indexing https://en.wikipedia.org/wiki/Capella_(notation_program)
# Indexing https://en.wikipedia.org/wiki/Webware_for_Python
# Indexing https://docs.python.org/2/faq/general.html
# Indexing https://en.wikipedia.org/wiki/Objective-C
# Indexing https://en.wikipedia.org/wiki/LAMP_(software_bundle)
# Indexing https://en.wikipedia.org/wiki/Falcon_(programming_language)
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=17
# Indexing https://en.wikipedia.org/wiki/C%2B%2B
# Indexing https://en.wikipedia.org/wiki/Special:BookSources/978-0-521-72596-5
# Indexing https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%AA%E0%A7%8D%E0%A6%B0%E0%A7%8B%E0%A6%97%E0%A7%8D%E0%A6%B0%E0%A6%BE%E0%A6%AE%E0%A6%BF%E0%A6%82_%E0%A6%AD%E0%A6%BE%E0%A6%B7%E0%A6%BE)
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=16
# Indexing https://en.wikipedia.org/wiki/Comparison_of_free_and_open-source_software_licenses
# Indexing https://en.wikipedia.org/wiki/PyQt
# Indexing https://en.wikipedia.org/wiki/Anaconda_(installer)
# Indexing https://en.wikipedia.org/wiki/ArcGIS
# Indexing https://en.wikipedia.org/wiki/PHP
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=15
# Indexing https://en.wikipedia.org/wiki/GNU_Debugger
# Indexing https://fr.wikipedia.org/wiki/Python_(langage)
# Indexing https://en.wikipedia.org/wiki/Exception_handling
# Indexing https://en.wikipedia.org/wiki/Eclipse_Public_License
# Indexing https://en.wikipedia.org/wiki/The_Document_Foundation
# Indexing https://en.wikipedia.org/wiki/Lock_(computer_science)
# Indexing https://en.wikipedia.org/wiki/SQLAlchemy
# Indexing https://docs.python.org/3/library/dis.html
# Indexing https://en.wikipedia.org/wiki/Variable_(computer_science)
# Indexing https://www.python.org/about/quotes/
# Indexing http://www.greenteapress.com/thinkpython/html/
# Could not open http://diveintopython3.net"
# <urlopen error [Errno 110] Connection timed out>
# Indexing https://en.wikipedia.org/wiki/Contributor_License_Agreement
# Indexing https://en.wikipedia.org/wiki/LEAP_(software_bundle)
# Indexing https://jbo.wikipedia.org/wiki/paiton
# Indexing https://fi.wikipedia.org/wiki/Python_(ohjelmointikieli)
# Indexing http://www.artima.com/intv/pythonP.html
# Indexing https://docs.python.org/library/functions.html
# Indexing https://en.wikipedia.org/wiki/GNU_Lesser_General_Public_License
# Indexing https://en.wikipedia.org/wiki/Ubuntu_(operating_system)
# Could not open http://sugarlabs.org/go/Sugar"
# HTTP Error 403: Bad Behavior
# Indexing https://ja.wikipedia.org/wiki/Python
# Indexing https://mr.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%AF%E0%A4%A5%E0%A5%89%E0%A4%A8
# Indexing https://en.wikipedia.org/wiki/List_of_programming_languages
# Indexing https://en.wikipedia.org/wiki/RPython
# Indexing https://en.wikipedia.org/wiki/Data_types
# Indexing http://community.eveonline.com/news/dev-blogs/stackless-python-2.7/
# Indexing https://af.wikipedia.org/wiki/Python_(programmeertaal)
# Indexing https://en.wikipedia.org/wiki/OpenBSD
# Indexing https://uz.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Dynamic_type
# Indexing https://en.wikipedia.org/wiki/Compile_time
# Indexing http://coffeescript.org/
# Indexing https://www.python.org/dev/buildbot/
# Indexing https://en.wikipedia.org/wiki/Iterator
# Indexing https://en.wikipedia.org/wiki/List_of_integrated_development_environments_for_Python
# Indexing https://en.wikipedia.org/wiki/Flask_(programming)
# Indexing https://en.wikipedia.org/wiki/CCP_Games
# Indexing https://en.wikipedia.org/wiki/Icon_(programming_language)
# Indexing https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%84%E0%B8%9E%E0%B8%97%E0%B8%AD%E0%B8%99
# Indexing https://tr.wikipedia.org/wiki/Python_(programlama_dili)
# Indexing https://en.wikipedia.org/wiki/Musical_notation
# Indexing https://en.wikipedia.org/wiki/Boolean_value
# Indexing https://en.wikipedia.org/wiki/.NET_Framework
# Indexing https://en.wikipedia.org/wiki/Cython
# Indexing https://lwn.net/Articles/627418/
# Indexing https://en.wikipedia.org/wiki/Mathematical_software
# Indexing https://ia.wikipedia.org/wiki/Python_(linguage_de_programmation)
# Indexing https://www.python.org/dev/peps/pep-0465/
# Indexing https://en.wikipedia.org/wiki/Generational_list_of_programming_languages
# Indexing https://en.wikipedia.org/wiki/Comparison_of_open-source_and_closed-source_software
# Indexing https://en.wikipedia.org/wiki/License_proliferation
# Indexing http://speakingjs.com/es5/ch03.html
# Indexing https://en.wikipedia.org/wiki/Aspect-oriented_programming
# Indexing https://en.wikipedia.org/wiki/Categorical_list_of_programming_languages
# Indexing https://en.wikipedia.org/w/index.php?title=Template:Python_web_frameworks&action=edit
# Indexing https://en.wikipedia.org/wiki/Command_line_interpreter
# Indexing https://en.wikipedia.org/wiki/TurboGears
# Indexing https://en.wikipedia.org/wiki/NumPy
# Indexing https://en.wikipedia.org/wiki/List_of_free_and_open-source_iOS_applications
# Indexing https://en.wikipedia.org/wiki/Swift_(Apple_programming_language)
# Indexing https://en.wikipedia.org/wiki/BSD_licenses
# Indexing https://en.wikipedia.org/wiki/OS_X
# Indexing https://en.wikipedia.org/wiki/Boost_Software_License
# Indexing https://fa.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86_(%D8%B2%D8%A8%D8%A7%D9%86_%D8%A8%D8%B1%D9%86%D8%A7%D9%85%D9%87%E2%80%8C%D9%86%D9%88%DB%8C%D8%B3%DB%8C)
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit
# Indexing https://en.wikipedia.org/wiki/Gentoo_Linux
# Indexing http://www.libreoffice.org/download/4-0-new-features-and-fixes/
# Indexing https://en.wikipedia.org/wiki/FreeBSD
# Indexing https://en.wikipedia.org/wiki/Portal:Free_software
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&oldid=715387675
# Indexing https://en.wikipedia.org/wiki/Comparison_of_open-source_programming_language_licensing
# Indexing https://en.wikipedia.org/wiki/Block_(programming)
# Indexing https://en.wikipedia.org/wiki/Comparison_of_integrated_development_environments
# Indexing https://en.wikipedia.org/wiki/GTK
# Indexing https://en.wikipedia.org/wiki/Rounding
# Indexing https://en.wikipedia.org/wiki/Boo_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Special:BookSources/978-0-9821060-1-3
# Indexing https://en.wikipedia.org/wiki/List_of_free_and_open-source_software_packages
# Indexing http://page.mi.fu-berlin.de/prechelt/Biblio/jccpprt_computer2000.pdf
# Indexing https://en.wikipedia.org/wiki/F_Sharp_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Zope
# Indexing https://en.wikipedia.org/wiki/Trusted_Computing
# Indexing https://en.wikipedia.org/wiki/Resource_Acquisition_Is_Initialization
# Indexing https://en.wikipedia.org/wiki/File:Python_logo_and_wordmark.svg
# Indexing https://en.wikipedia.org/wiki/Wikipedia:Good_articles
# Indexing https://en.wikipedia.org/wiki/Perl
# Indexing https://en.wikipedia.org/wiki/Lightwave
# Indexing https://en.wikipedia.org/wiki/List_comprehensions
# Indexing https://en.wikipedia.org/wiki/Talk:Python_(programming_language)
# Indexing http://blog.python.org/2015/12/python-351-and-python-344rc1-are-now.html
# Indexing https://en.wikipedia.org/wiki/PyPy
# Indexing https://en.wikipedia.org/wiki/Stack_Overflow
# Indexing http://www.qtrac.eu/py3book.html
# Indexing https://en.wikipedia.org/wiki/Neologism
# Indexing https://as.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8
# Indexing https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# Indexing https://en.wikipedia.org/wiki/Paint_Shop_Pro
# Indexing https://en.wikipedia.org/wiki/Main_Page
# Indexing https://en.wikipedia.org/wiki/Integer_(computer_science)
# Indexing https://en.wikipedia.org/wiki/History_of_Python
# Indexing https://www.python.org/downloads/release/python-2711/
# Indexing https://en.wikipedia.org/wiki/Hacker_(programmer_subculture)
# Indexing http://cobra-language.com/docs/acknowledgements/
# Indexing http://pypy.org/compat.html
# Indexing https://en.wikipedia.org/wiki/File:Portal-puzzle.svg
# Indexing https://en.wikipedia.org/wiki/Category:High-level_programming_languages
# Indexing http://www.2kgames.com/civ4/blog_03.htm
# Indexing https://en.wikipedia.org/wiki/Pygame
# Indexing https://en.wikipedia.org/wiki/Dropbox_(service)
# Indexing https://en.wikipedia.org/wiki/Software_design
# Indexing https://en.wikipedia.org/wiki/Foobar
# Indexing https://en.wikipedia.org/wiki/Series_60
# Indexing https://en.wikipedia.org/wiki/Pyladies
# Indexing https://mn.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Data_mapper_pattern
# Indexing https://en.wikipedia.org/wiki/S60_(software_platform)
# Indexing https://en.wikipedia.org/wiki/REPL
# Indexing https://hu.wikipedia.org/wiki/Python_(programoz%C3%A1si_nyelv)
# Indexing https://en.wikipedia.org/wiki/Open-source_movement
# Indexing https://en.wikipedia.org/wiki/Category:Programming_languages_created_in_1991
# Indexing https://en.wikipedia.org/wiki/Premature_optimization
# Indexing https://en.wikipedia.org/wiki/Multi-core_processor
# Indexing https://en.wikipedia.org/wiki/Netherlands
# Indexing https://en.wikipedia.org/wiki/Python_IDE
# Indexing https://en.wikipedia.org/wiki/Special:Random
# Indexing https://en.wikipedia.org/wiki/List_of_open-source_health_software
# Indexing https://en.wikipedia.org/wiki/ITA_Software
# Indexing https://en.wikipedia.org/wiki/Copyfree
# Indexing https://en.wikipedia.org/wiki/CPython
# Indexing https://en.wikipedia.org/wiki/Python_(disambiguation)
# Indexing https://en.wikipedia.org/wiki/Software_patents_and_free_software
# Indexing https://en.wikipedia.org/wiki/Gratis_versus_libre
# Indexing https://en.wikipedia.org/wiki/Definition_of_Free_Cultural_Works
# Indexing https://en.wikipedia.org/wiki/Quixote_(web_framework)
# Indexing https://en.wikipedia.org/wiki/Wikipedia:About
# Indexing https://ms.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Sugar_(GUI)
# Indexing https://en.wikipedia.org/wiki/Monty_Python%27s_Flying_Circus
# Indexing https://docs.python.org/tutorial/classes.html
# Indexing https://en.wikipedia.org/wiki/UEFI_Secure_Boot
# Indexing https://en.wikipedia.org/wiki/Psyco
# Indexing https://en.wikipedia.org/wiki/Off-side_rule
# Indexing https://en.wikipedia.org/wiki/Set_(computer_science)
# Indexing https://en.wikipedia.org/wiki/Scorewriter
# Indexing https://en.wikipedia.org/wiki/International_Standard_Book_Number
# Indexing https://en.wikipedia.org/wiki/Common_Development_and_Distribution_License
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=9
# Indexing http://www.computerworld.com.au/index.php/id;66665771
# Indexing https://en.wikipedia.org/wiki/First-class_continuations
# Indexing http://python.net/crew/mwh/hacks/objectthink.html
# Indexing http://www.ainewsletter.com/newsletters/aix_0508.htm
# Indexing https://de.wikipedia.org/wiki/Python_(Programmiersprache)
# Indexing https://docs.python.org/2/library/pprint.html
# Indexing http://www.webcitation.org/5ru5FHxfV
# Indexing https://en.wikipedia.org/wiki/Number_theory
# Indexing https://en.wikipedia.org/wiki/Assembly_language
# Indexing https://en.wikipedia.org/wiki/Curly_bracket_programming_language
# Indexing https://en.wikipedia.org/wiki/Unit_test
# Indexing https://en.wikipedia.org/wiki/Type_system
# Indexing https://en.wikipedia.org/wiki/OCaml
# Indexing https://en.wikipedia.org/wiki/Virtual_machine
# Indexing http://www.techcrunch.com/2009/11/10/google-go-language/
# Indexing https://en.wikipedia.org/wiki/Java_(programming_language)
# Indexing https://en.wikipedia.org/wiki/List_of_free_software_project_directories
# Indexing https://en.wikipedia.org/wiki/Self-hosted
# Indexing https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Python+%28programming+language%29&type=signup
# Indexing https://github.com/stevengj/PyCall.jl
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=7
# Indexing https://en.wikipedia.org/wiki/Special:BookSources/978-1-59059-881-8
# Indexing https://en.wikipedia.org/wiki/N900
# Indexing https://en.wikipedia.org/wiki/BioPython
# Indexing http://d-nb.info/gnd/4434275-5
# Indexing https://code.google.com/p/unladen-swallow/wiki/ProjectPlan
# Indexing https://en.wikipedia.org/wiki/Programming_language_implementation
# Indexing https://pt.wikipedia.org/wiki/Python
# Indexing https://da.wikipedia.org/wiki/Python_(programmeringssprog)
# Indexing https://lv.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Abaqus
# Indexing https://www.python.org/dev/peps/pep-0342/
# Indexing https://en.wikipedia.org/wiki/Multi-paradigm_programming_language
# Indexing http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.38.2023
# Indexing https://en.wikipedia.org/wiki/Modula-3
# Indexing https://en.wikipedia.org/wiki/Proprietary_software
# Indexing http://www.oreilly.com/pub/a/oreilly/frank/rossum_1099.html
# Indexing https://en.wikipedia.org/w/index.php?title=Special:Book&bookcmd=render_article&arttitle=Python+%28programming+language%29&returnto=Python+%28programming+language%29&oldid=715387675&writer=rdf2latex
# Indexing https://en.wikipedia.org/wiki/Academic_conference
# Indexing https://en.wikipedia.org/wiki/Softimage_XSI
# Indexing https://www.wikimediafoundation.org/
# Indexing https://www.python.org/dev/peps/pep-0441/
# Indexing https://en.wikipedia.org/wiki/Standard_library
# Indexing https://en.wikipedia.org/wiki/Design_by_contract
# Indexing https://en.wikipedia.org/wiki/Free_software
# Indexing https://en.wikipedia.org/wiki/Metasyntactic_variable
# Indexing https://en.wikipedia.org/wiki/Portal:Contents
# Indexing https://en.wikipedia.org/wiki/Cross-platform
# Indexing https://en.wikipedia.org/wiki/Open-source_license
# Indexing http://mail.python.org/pipermail/python-dev/2000-August/008881.html
# Indexing https://tl.wikipedia.org/wiki/Python_(wikang_pamprograma)
# Indexing https://en.wikipedia.org/wiki/Go_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Reflective_programming
# Indexing https://en.wikipedia.org/wiki/Permissive_free_software_licence
# Indexing https://en.wikipedia.org/wiki/Outline_of_free_software
# Indexing https://en.wikipedia.org/wiki/Complex_number
# Indexing https://en.wikipedia.org/wiki/Dynamic_programming_language
# Indexing https://en.wikipedia.org/wiki/O%27Reilly_Media
# Indexing https://en.wikipedia.org/wiki/Mozilla
# Indexing https://ca.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Conditional_(programming)
# Indexing https://en.wikipedia.org/wiki/Open-source_software_security
# Indexing https://en.wikipedia.org/wiki/Google_App_Engine
# Indexing https://en.wikipedia.org/wiki/Category:Cross-platform_free_software
# Indexing https://en.wikipedia.org/wiki/Readability
# Indexing https://en.wikipedia.org/wiki/Metaprogramming
# Indexing https://en.wikipedia.org/wiki/ECMAScript
# Indexing https://www.python.org/dev/peps/pep-0001/
# Indexing https://en.wikipedia.org/wiki/Regular_expression
# Indexing https://www.python.org/dev/peps/pep-0238/
# Indexing https://en.wikipedia.org/wiki/Microsoft_Windows
# Indexing https://en.wikipedia.org/wiki/Method_(programming)
# Indexing https://en.wikipedia.org/wiki/WTFPL
# Indexing https://en.wikipedia.org/wiki/DMOZ
# Indexing https://en.wikipedia.org/wiki/CERN
# Indexing https://en.wikipedia.org/wiki/Spam_(Monty_Python)
# Indexing https://mail.python.org/mailman/listinfo/python-list
# Indexing https://en.wikipedia.org/wiki/Spyce
# Indexing https://en.wikipedia.org/wiki/Free_license
# Indexing https://be.wikipedia.org/wiki/Python,_%D0%BC%D0%BE%D0%B2%D0%B0_%D0%BF%D1%80%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%B0%D0%B2%D0%B0%D0%BD%D0%BD%D1%8F
# Indexing http://doc.pypy.org/en/latest/stackless.html
# Indexing https://en.wikipedia.org/wiki/BuildBot
# Indexing https://en.wikipedia.org/wiki/Unix
# Indexing https://en.wikipedia.org/wiki/There_is_more_than_one_way_to_do_it
# Indexing https://en.wikipedia.org/wiki/Jython
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=20
# Indexing https://en.wikipedia.org/wiki/File:Guido_van_Rossum_OSCON_2006.jpg
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=13
# Indexing http://inventwithpython.com/appendixa.html
# Indexing https://en.wikipedia.org/wiki/Mozilla_Public_License
# Indexing https://en.wikipedia.org/wiki/Category:Wikipedia_articles_with_GND_identifiers
# Indexing https://en.wikipedia.org/wiki/Maya_(software)
# Indexing https://sv.wikipedia.org/wiki/Python_(programspr%C3%A5k)
# Indexing https://wiki.gnome.org/action/show/Projects/Genie
# Indexing https://en.wikipedia.org/wiki/Template_talk:FOSS
# Indexing https://en.wikipedia.org/wiki/Language_binding
# Indexing https://en.wikipedia.org/wiki/Unladen_Swallow
# Indexing https://en.wikipedia.org/wiki/PyGTK
# Indexing https://www.python.org/about
# Indexing https://en.wikipedia.org/wiki/Arbitrary_precision_arithmetic
# Indexing https://en.wikipedia.org/wiki/Genie_(programming_language)
# Indexing https://es.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Timeline_of_programming_languages
# Indexing https://en.wikipedia.org/wiki/MotionBuilder
# Indexing https://en.wikipedia.org/wiki/List_of_Python_software
# Indexing https://en.wikipedia.org/wiki/Python_for_S60
# Indexing https://en.wikipedia.org/wiki/List_comprehension
# Indexing https://ka.wikipedia.org/wiki/%E1%83%9E%E1%83%98%E1%83%97%E1%83%9D%E1%83%9C%E1%83%98_(%E1%83%9E%E1%83%A0%E1%83%9D%E1%83%92%E1%83%A0%E1%83%90%E1%83%9B%E1%83%98%E1%83%A0%E1%83%94%E1%83%91%E1%83%98%E1%83%A1_%E1%83%94%E1%83%9C%E1%83%90)
# Indexing https://en.wikipedia.org/wiki/IronPython
# Indexing https://sq.wikipedia.org/wiki/Python
# Indexing http://www.jasc.com/support/customercare/articles/psp9components.asp
# Indexing https://en.wikipedia.org/wiki/Hardware_restriction
# Indexing https://docs.python.org/2.6/whatsnew/2.6.html
# Indexing https://en.wikipedia.org/wiki/Prettyprint
# Indexing https://en.wikipedia.org/wiki/Category:Wikipedia_articles_needing_page_number_citations_from_January_2012
# Indexing https://en.wikipedia.org/wiki/Cinema_4D
# Indexing https://en.wikipedia.org/wiki/NOP
# Indexing https://en.wikipedia.org/wiki/Bytecode
# Indexing https://en.wikipedia.org/wiki/History_of_Haiku_(operating_system)
# Indexing https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# Indexing https://en.wikipedia.org/wiki/Mod_wsgi
# Indexing https://en.wikipedia.org/w/index.php?title=Special:Book&bookcmd=book_creator&referer=Python+%28programming+language%29
# Indexing https://docs.python.org/howto/functional.html
# Could not open http://www.amk.ca/python/writing/gvr-interview"
# HTTP Error 404: Not Found
# Indexing https://en.wikipedia.org/wiki/JavaScript
# Indexing https://en.wikipedia.org/wiki/Software_license
# Indexing https://en.wikipedia.org/wiki/Template:FOSS
# Indexing https://en.wikipedia.org/wiki/Duck_typing
# Indexing https://en.wikipedia.org/wiki/Amoeba_(operating_system)
# Indexing http://www.nongnu.org/pydbc/
# Indexing http://docs.oracle.com/javase/specs/jls/se8/html/jls-15.html
# Indexing https://en.wikipedia.org/wiki/File:Free_and_open-source_software_logo_(2009).svg
# Indexing https://az.wikipedia.org/wiki/Python_(proqramla%C5%9Fd%C4%B1rma_dili)
# Indexing https://en.wikipedia.org/wiki/Generator_(computer_programming)
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=2
# Indexing https://en.wikipedia.org/wiki/History_of_Linux
# Indexing https://en.wikipedia.org/wiki/Aphorism
# Indexing https://en.wikipedia.org/wiki/List_of_content_management_systems
# Indexing https://en.wikipedia.org/wiki/Shared_source
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=11
# Indexing https://en.wikipedia.org/wiki/List_of_trademarked_open-source_software
# Indexing https://en.wikipedia.org/wiki/Ellipsis_(programming_operator)
# Indexing https://en.wikipedia.org/wiki/Imperative_programming
# Indexing https://sl.wikipedia.org/wiki/Python_(programski_jezik)
# Indexing https://www.python.org/
# Indexing https://en.wikipedia.org/wiki/Special:BookSources/978-0-596-00797-3
# Indexing https://en.wikipedia.org/wiki/Comparison_of_open-source_configuration_management_software
# Indexing https://en.wikipedia.org/wiki/Pyjamas_(software)
# Indexing https://en.wikipedia.org/wiki/FreeCAD
# Indexing https://en.wikipedia.org/wiki/SCO/Linux_controversies
# Indexing https://en.wikipedia.org/wiki/Metaclass
# Indexing https://no.wikipedia.org/wiki/Python
# Indexing http://www.nltk.org
# Indexing https://github.com/JuliaLang/pyjulia
# Could not open http://oss.coresecurity.com/"
# Remote end closed connection without response
# Indexing https://en.wikipedia.org/w/index.php?title=Template:Programming_languages&action=edit
# Indexing https://en.wikipedia.org/wiki/List_of_free_television_software
# Indexing https://en.wikipedia.org/wiki/Zen_of_Python
# Indexing http://nondot.org/sabre/
# Indexing http://www.tiobe.com/index.php/content/paperinfo/tpci/index.html
# Indexing https://en.wikipedia.org/wiki/Function_(computing)
# Indexing https://hr.wikipedia.org/wiki/Python_(programski_jezik)
# Indexing http://id.loc.gov/authorities/subjects/sh96008834
# Indexing https://en.wikipedia.org/wiki/Functional_programming
# Indexing https://en.wikipedia.org/wiki/Raspberry_Pi
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=8
# Indexing http://boo.codehaus.org/Gotchas+for+Python+Users
# Indexing https://en.wikipedia.org/wiki/Scheme_(programming_language)
# Indexing http://python.net/~goodger/projects/pycon/2007/idiomatic/handout.html
# Indexing http://morepypy.blogspot.be/2012/06/stm-with-threads.html
# Indexing https://en.wikipedia.org/wiki/Category:Text-oriented_programming_languages
# Indexing https://wiki.python.org/moin/OrganizationsUsingPython
# Indexing https://sites.google.com/site/pydatalog/
# Indexing https://en.wikipedia.org/wiki/C_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Comparison_of_free_software_e-commerce_web_application_frameworks
# Indexing https://en.wikipedia.org/wiki/Integrated_Authority_File
# Indexing https://en.wikipedia.org/wiki/Category:Articles_with_DMOZ_links
# Could not open http://stackoverflow.com/questions/5033906/in-python-should-i-use-else-after-a-return-in-an-if-block"
# HTTP Error 403: Forbidden
# Indexing https://docs.python.org/faq/general.html
# Indexing https://en.wikipedia.org/wiki/Software_release_life_cycle
# Indexing https://en.wikipedia.org/wiki/Modo_(software)
# Indexing https://en.wikipedia.org/wiki/Strong_typing
# Indexing https://en.wikipedia.org/wiki/TIOBE_Programming_Community_Index
# Indexing https://en.wikipedia.org/wiki/Software_transactional_memory
# Indexing https://en.wikipedia.org/wiki/List_of_collaborative_software
# Indexing https://en.wikipedia.org/wiki/PyS60
# Indexing https://docs.python.org/tutorial/appetite.html
# Indexing https://en.wikipedia.org/wiki/Lisp_(programming_language)
# Indexing https://www.mediawiki.org/
# Indexing https://en.wikipedia.org/wiki/Bash_(Unix_shell)
# Indexing https://en.wikipedia.org/wiki/Alternative_terms_for_free_software
# Indexing https://code.google.com/apis/documents/docs/1.0/developers_guide_python.html
# Indexing https://en.wikipedia.org/wiki/Foreach
# Indexing http://www.eweek.com/c/a/Application-Development/Python-Slithers-into-Systems/
# Indexing http://www.python.org
# Indexing https://en.wikipedia.org/wiki/Web_application
# Indexing https://en.wikipedia.org/wiki/SETL
# Indexing https://en.wikipedia.org/wiki/Hygienic_macro
# Indexing https://en.wikipedia.org/wiki/Wikipedia:Contact_us
# Indexing https://en.wikipedia.org/wiki/Digital_rights_management
# Indexing https://en.wikipedia.org/wiki/Combinatorics
# Indexing https://en.wikipedia.org/wiki/Package_management_system
# Indexing https://en.wikipedia.org/wiki/Unix_shell
# Indexing https://docs.python.org/devguide/
# Indexing http://www.oracle.com/technetwork/articles/piotrowski-pythoncore-084049.html
# Indexing https://www.python.org/dev/peps/pep-0318/
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=6
# Indexing https://en.wikipedia.org/wiki/Usenet
# Indexing https://en.wikipedia.org/wiki/Dynamic_typing
# Indexing https://en.wikipedia.org/wiki/Common_Language_Runtime
# Indexing http://w3techs.com/technologies/details/pl-python/all/all
# Indexing https://en.wikipedia.org/wiki/Microthread
# Indexing https://www.python.org/dev/peps/pep-0308/
# Indexing https://en.wikipedia.org/wiki/Array_index
# Indexing https://en.wikipedia.org/wiki/Web_Server_Gateway_Interface
# Indexing https://en.wikipedia.org/wiki/Ninja-IDE
# Indexing https://en.wikipedia.org/wiki/Beta_release
# Indexing https://en.wikipedia.org/wiki/Special:BookSources/978-0-13-604259-4
# Could not open http://redmonk.com/sogrady/2015/07/01/language-rankings-6-15/"
# HTTP Error 403: Forbidden
# Indexing https://en.wikipedia.org/wiki/Specialising_compiler
# Indexing https://en.wikipedia.org/wiki/Fork_(software_development)
# Indexing https://en.wikipedia.org/wiki/PyCon
# Indexing https://en.wikipedia.org/wiki/Google_Groups
# Indexing https://www.python.org/about/success/usa/
# Indexing https://pypi.python.org/pypi/PyAIML
# Indexing https://nds.wikipedia.org/wiki/Python_(Programmeerspraak)
# Indexing https://en.wikipedia.org/wiki/Continuous_integration
# Indexing https://en.wikipedia.org/wiki/Category:Programming_languages
# Indexing https://en.wikipedia.org/wiki/Interpreter_(computing)
# Indexing https://en.wikipedia.org/wiki/Copyleft
# Indexing https://en.wikipedia.org/wiki/Special:MyTalk
# Indexing https://en.wikipedia.org/wiki/Binary_blob
# Indexing https://zh.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Function_(programming)
# Indexing https://groups.google.com/group/comp.lang.python
# Indexing https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer
# Indexing https://ne.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8_%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%BF%E0%A4%99%E0%A5%8D%E0%A4%97_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE
# Indexing https://en.wikipedia.org/wiki/Zero-based
# Indexing https://en.wikipedia.org/wiki/High-level_programming_language
# Indexing https://en.wikipedia.org/wiki/NASA
# Indexing https://en.wikipedia.org/wiki/GIMP
# Indexing https://en.wikipedia.org/wiki/Apache_License
# Indexing https://en.m.wikipedia.org/w/index.php?title=Python_(programming_language)&mobileaction=toggle_view_mobile
# Indexing https://en.wikipedia.org/wiki/AmigaOS_4
# Indexing https://en.wikipedia.org/wiki/If-then-else
# Indexing https://en.wikipedia.org/wiki/Special:BookSources/978-0-596-15806-4
# Indexing https://id.wikipedia.org/wiki/Python_(bahasa_pemrograman)
# Indexing https://en.wikipedia.org/wiki/Java_bytecode
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=18
# Indexing https://docs.python.org/3.0/reference/datamodel.html
# Indexing https://en.wikipedia.org/wiki/Qt_(framework)
# Indexing http://www.tcl.tk/cgi-bin/tct/tip/3.html
# Indexing https://en.wikipedia.org/wiki/Special:WhatLinksHere/Python_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Special:BookSources/978-0-321-68056-3
# Indexing https://en.wikipedia.org/wiki/CherryPy
# Indexing https://mk.wikipedia.org/wiki/%D0%9F%D0%B0%D1%98%D1%82%D0%BE%D0%BD_(%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B0%D0%B7%D0%B8%D0%BA)
# Indexing https://en.wikipedia.org/wiki/Logic_programming
# Indexing https://en.wikipedia.org/wiki/Tcl
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=12
# Indexing https://en.wikipedia.org/wiki/Special:SpecialPages
# Indexing https://te.wikipedia.org/wiki/%E0%B0%AA%E0%B1%88%E0%B0%A5%E0%B0%BE%E0%B0%A8%E0%B1%8D_(%E0%B0%95%E0%B0%82%E0%B0%AA%E0%B1%8D%E0%B0%AF%E0%B1%82%E0%B0%9F%E0%B0%B0%E0%B1%8D_%E0%B0%AD%E0%B0%BE%E0%B0%B7)
# Indexing https://en.wikipedia.org/wiki/BASIC
# Indexing https://www.python.org/dev/peps/pep-0020/
# Indexing https://en.wikipedia.org/wiki/Calculus
# Indexing https://en.wikipedia.org/wiki/Revolution_OS
# Indexing https://commons.wikimedia.org/wiki/Category:Free_software
# Indexing https://en.wikipedia.org/wiki/List_of_open-source_codecs
# Could not open http://gimp-win.sourceforge.net/faq.html"
# HTTP Error 404: Not Found
# Indexing https://en.wikipedia.org/wiki/CC0
# Indexing https://en.wikipedia.org/wiki/Round_to_even
# Indexing https://en.wikipedia.org/wiki/3ds_Max
# Indexing https://docs.python.org/2.7/library/stdtypes.html
# Indexing https://en.wikipedia.org/wiki/IDLE_(Python)
# Indexing https://en.wikipedia.org/wiki/Category:Class-based_programming_languages
# Indexing https://en.wikipedia.org/wiki/Esri
# Indexing http://webhelp.esri.com/arcgisdesktop/9.2/index.cfm?TopicName=About_getting_started_with_writing_geoprocessing_scripts
# Indexing https://gl.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Scripting_language
# Indexing https://www.python.org/doc/essays/foreword/
# Indexing https://nl.wikipedia.org/wiki/Python_(programmeertaal)
# Indexing https://en.wikipedia.org/wiki/List_of_statistical_packages
# Indexing http://shop.oreilly.com/product/0636920028154.do
# Indexing https://www.python.org/about/success/ilm/
# Indexing https://en.wikipedia.org/wiki/Book:Free_and_Open_Source_Software
# Could not open http://www.erlang.org/eeps/eep-0001.html"
# HTTP Error 301: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Moved Permanently
# Indexing https://en.wikipedia.org/wiki/Ruby_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Syntactic_sugar
# Indexing https://en.wikipedia.org/wiki/History_of_programming_languages
# Indexing http://www.webcitation.org/5lubkaJRc
# Indexing https://en.wikipedia.org/wiki/Stackless_Python
# Indexing https://en.wikipedia.org/wiki/Shed_Skin
# Indexing https://en.wikipedia.org/wiki/List_of_commercial_open-source_applications_and_services
# Indexing https://en.wikipedia.org/wiki/Category:Scripting_languages
# Indexing https://en.wikipedia.org/w/index.php?title=Special:CiteThisPage&page=Python_%28programming_language%29&id=715387675
# Indexing https://en.wikipedia.org/wiki/History_of_free_and_open-source_software
# Indexing https://en.wikipedia.org/wiki/Source_lines_of_code
# Indexing https://en.wikipedia.org/wiki/Category:Educational_programming_languages
# Indexing https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=10
# Indexing https://en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard
# Indexing https://en.wikipedia.org/wiki/This_(computer_programming)
# Indexing https://en.wikipedia.org/wiki/Pylons_project
# Indexing https://en.wikipedia.org/wiki/IPython
# Indexing https://is.wikipedia.org/wiki/Python_(forritunarm%C3%A1l)
# Indexing https://en.wikipedia.org/wiki/Template:Python_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Firaxis_Games
# Indexing https://en.wikipedia.org/wiki/Free_and_open-source_software
# Indexing https://hy.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/Third-party_software_component
# Indexing https://en.wikipedia.org/wiki/TIOBE_index
# Indexing https://en.wikipedia.org/wiki/Comparison_of_open-source_wireless_drivers
# Indexing https://web.archive.org/20090601134342/http://www.python.org:80/dev/intro/
# Indexing https://en.wikipedia.org/wiki/Stani%27s_Python_Editor
# Indexing https://en.wikipedia.org/wiki/Houdini_(software)
# Indexing https://en.wikipedia.org/wiki/ISC_license
# Indexing https://en.wikipedia.org/wiki/Chris_Lattner
# Indexing https://en.wikipedia.org/wiki/Portal:Featured_content
# Indexing https://sh.wikipedia.org/wiki/Python_programski_jezik
# Indexing https://en.wikipedia.org/wiki/Help:Category
# Indexing https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Python+%28programming+language%29
# Indexing https://en.wikipedia.org/wiki/Erlang_(programming_language)
# Indexing https://en.wikipedia.org/wiki/Python_Conference
# Indexing https://en.wikipedia.org/wiki/Stuart_J._Russell
# Indexing https://uk.wikipedia.org/wiki/Python
# Indexing https://en.wikipedia.org/wiki/%3F:
# Indexing https://en.wikipedia.org/wiki/Magic_methods
# Indexing https://en.wikipedia.org/wiki/Public_domain
# Indexing https://en.wikipedia.org/wiki/Special:BookSources/978-1-4302-2415-0
# Indexing https://en.wikipedia.org/wiki/Yahoo!
# Indexing https://en.wikipedia.org/wiki/PyDev
